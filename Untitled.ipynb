# %%
#Climate Change Impact on Agricultural Land Suitability: An Interpretable Machine Learning-Based Eurasia Case Study

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("climate_agriculture_high_accuracy_dataset.csv")
df
# Out:
#                 Region  Soil_Quality_Index  Annual_Rainfall_mm  Temperature_C  \
# 0      Central Eurasia                0.43               449.0           11.2
# 1       Eastern Europe                0.53               625.2           13.0
# 2        Northern Asia                0.60               908.0           18.2
# 3       Eastern Europe                0.54               684.9           12.2
# 4       Eastern Europe                0.35               635.5           18.7
# ...                ...                 ...                 ...            ...
# 11995   Eastern Europe                0.12               648.3           16.9
# 11996  Central Eurasia                0.97               745.8           13.8
# 11997    Northern Asia                0.10               509.2           15.8
# 11998   Eastern Europe                0.88               585.2           16.6
# 11999   Eastern Europe                0.34               662.3           22.6
#
# ...

# %%
df['Region'].unique()
# Out:
# array([0, 1, 2])

# %%
df.head()
# Out:
#             Region  Soil_Quality_Index  Annual_Rainfall_mm  Temperature_C  \
# 0  Central Eurasia                0.43               449.0           11.2
# 1   Eastern Europe                0.53               625.2           13.0
# 2    Northern Asia                0.60               908.0           18.2
# 3   Eastern Europe                0.54               684.9           12.2
# 4   Eastern Europe                0.35               635.5           18.7
#
#   Irrigation_Level CO2_Emission_Scenario  Water_Availability_Index  \
# 0              Low                  High                      0.57
# 1           Medium                  High                      0.57
# 2              Low                  High                      0.57
# 3           Medium                  High                      0.61
# 4             High                Medium                      0.34
#
#   Fertilizer_Access Land_Degradation_Risk Land_Suitability
# ...

# %%
df.tail()
# Out:
#                 Region  Soil_Quality_Index  Annual_Rainfall_mm  Temperature_C  \
# 11995   Eastern Europe                0.12               648.3           16.9
# 11996  Central Eurasia                0.97               745.8           13.8
# 11997    Northern Asia                0.10               509.2           15.8
# 11998   Eastern Europe                0.88               585.2           16.6
# 11999   Eastern Europe                0.34               662.3           22.6
#
#       Irrigation_Level CO2_Emission_Scenario  Water_Availability_Index  \
# 11995           Medium                Medium                      0.11
# 11996           Medium                Medium                      0.97
# 11997           Medium                  High                      0.17
# 11998             High                  High                      0.88
# 11999           Medium                  High                      0.15
#
#       Fertilizer_Access Land_Degradation_Risk Land_Suitability
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    12000 non-null  object
#  1   Soil_Quality_Index        12000 non-null  float64
#  2   Annual_Rainfall_mm        12000 non-null  float64
#  3   Temperature_C             12000 non-null  float64
#  4   Irrigation_Level          12000 non-null  object
#  5   CO2_Emission_Scenario     12000 non-null  object
#  6   Water_Availability_Index  12000 non-null  float64
#  7   Fertilizer_Access         12000 non-null  object
#  8   Land_Degradation_Risk     12000 non-null  object
#  9   Land_Suitability          12000 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#        Soil_Quality_Index  Annual_Rainfall_mm  Temperature_C  \
# count        12000.000000        12000.000000   12000.000000
# mean             0.500662          700.833267      17.996367
# std              0.288132           99.800781       3.008010
# min              0.000000          331.500000       6.600000
# 25%              0.250000          634.100000      16.000000
# 50%              0.500000          699.100000      18.000000
# 75%              0.750000          768.825000      20.000000
# max              1.000000         1068.900000      31.100000
#
#        Water_Availability_Index
# count              12000.000000
# mean                   0.502157
# std                    0.295553
# min                    0.000000
# 25%                    0.250000
# 50%                    0.500000
# 75%                    0.750000
# max                    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a count plot
sns.set(style="darkgrid")  # Set the style of the plot
plt.figure(figsize=(10, 10))  # Set the figure size
ax = sns.countplot(x='Land_Suitability', data=df)
plt.title("Count Plot")  # Add a title to the plot
plt.xlabel("Categories")  # Add label to x-axis
plt.ylabel("Count")  # Add label to y-axis
# Annotate each bar with its count value
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %%
df.isnull().sum()
# Out:
# Region                      0
# Soil_Quality_Index          0
# Annual_Rainfall_mm          0
# Temperature_C               0
# Irrigation_Level            0
# CO2_Emission_Scenario       0
# Water_Availability_Index    0
# Fertilizer_Access           0
# Land_Degradation_Risk       0
# Land_Suitability            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Land_Suitability"].unique()
# Out:
# array(['Unsuitable', 'Moderate', 'Highly Suitable'], dtype=object)

# %%
df["Land_Suitability"].nunique()
# Out:
# 3

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Land_Suitability"]=le.fit_transform(df["Land_Suitability"])
df["Region"]=le.fit_transform(df["Region"])
df["Irrigation_Level"]=le.fit_transform(df["Irrigation_Level"])
df["CO2_Emission_Scenario"]=le.fit_transform(df["CO2_Emission_Scenario"])
df["Fertilizer_Access"]=le.fit_transform(df["Fertilizer_Access"])
df["Land_Degradation_Risk"]=le.fit_transform(df["Land_Degradation_Risk"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    12000 non-null  int32
#  1   Soil_Quality_Index        12000 non-null  float64
#  2   Annual_Rainfall_mm        12000 non-null  float64
#  3   Temperature_C             12000 non-null  float64
#  4   Irrigation_Level          12000 non-null  int32
#  5   CO2_Emission_Scenario     12000 non-null  int32
#  6   Water_Availability_Index  12000 non-null  float64
#  7   Fertilizer_Access         12000 non-null  int32
#  8   Land_Degradation_Risk     12000 non-null  int32
#  9   Land_Suitability          12000 non-null  int32
# dtypes: float64(4), int32(6)
# memory usage: 656.4 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a count plot
sns.set(style="darkgrid")  # Set the style of the plot
plt.figure(figsize=(10, 10))  # Set the figure size
ax = sns.countplot(x='Land_Suitability', data=df)
plt.title("Count Plot")  # Add a title to the plot
plt.xlabel("Categories")  # Add label to x-axis
plt.ylabel("Count")  # Add label to y-axis
# Annotate each bar with its count value
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %%
labels=['Unsuitable', 'Moderate', 'Highly Suitable']

# %%
x=df.iloc[:,1:-1]

# %%
x
# Out:
#        Soil_Quality_Index  Annual_Rainfall_mm  Temperature_C  \
# 0                    0.43               449.0           11.2
# 1                    0.53               625.2           13.0
# 2                    0.60               908.0           18.2
# 3                    0.54               684.9           12.2
# 4                    0.35               635.5           18.7
# ...                   ...                 ...            ...
# 11995                0.12               648.3           16.9
# 11996                0.97               745.8           13.8
# 11997                0.10               509.2           15.8
# 11998                0.88               585.2           16.6
# 11999                0.34               662.3           22.6
#
#        Irrigation_Level  CO2_Emission_Scenario  Water_Availability_Index  \
# 0                     1                      0                      0.57
# 1                     2                      0                      0.57
# ...

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        2
#         ..
# 11995    2
# 11996    1
# 11997    2
# 11998    2
# 11999    2
# Name: Land_Suitability, Length: 12000, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train.shape
# Out:
# (9600, 8)

# %%
y_train.shape
# Out:
# (9600,)

# %%
x_test.shape
# Out:
# (2400, 8)

# %%
y_test.shape
# Out:
# (2400,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
accuracy=[]
precision=[]
recall=[]
fscore=[]

# %%
#function to calculate various metrics such as accuracy, precision etc
def calculateMetrics(algorithm, testY,predict):
    Labels = ["Normal_Attack", "DDoS_Attack"] 
    p = precision_score(testY, predict,average='macro') * 100
    r = recall_score(testY, predict,average='macro') * 100
    f = f1_score(testY, predict,average='macro') * 100
    a = accuracy_score(testY,predict)*100 
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    print(algorithm+' Accuracy    : '+str(a))
    print(algorithm+' Precision   : '+str(p))
    print(algorithm+' Recall      : '+str(r))
    print(algorithm+' FSCORE      : '+str(f))
    report=classification_report(predict, testY,target_names=labels)
    print('\n',algorithm+" classification report\n",report)
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize =(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="Blues" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %%
import os
import joblib
from sklearn.ensemble import RandomForestClassifier

# Ensure the model directory exists
os.makedirs('model', exist_ok=True)

# Define the model file path
model_path = 'model/RandomForestClassifier.pkl'

if os.path.exists(model_path):
    # Load the trained model from the file
    rf = joblib.load(model_path)
    print("RandomForestClassifier model loaded successfully.")
    y_pred = rf.predict(x_test)
    calculateMetrics("RandomForestClassifier", y_pred, y_test)
else:
    # Train the model (assuming x_train and y_train are defined)
    rf = RandomForestClassifier()
    rf.fit(x_train, y_train)
    # Save the trained model to a file
    joblib.dump(rf, model_path)
    print("RandomForestClassifier model saved successfully.")
    y_pred = rf.predict(x_test)
    calculateMetrics("RandomForestClassifier", y_pred, y_test)
# Out:
# RandomForestClassifier model saved successfully.
# RandomForestClassifier Accuracy    : 99.83333333333333
# RandomForestClassifier Precision   : 99.55785937338129
# RandomForestClassifier Recall      : 99.28527780281333
# RandomForestClassifier FSCORE      : 99.42072553928853
#
#  RandomForestClassifier classification report
#                   precision    recall  f1-score   support
#
#      Unsuitable       0.98      0.99      0.99       101
#        Moderate       1.00      1.00      1.00       892
# Highly Suitable       1.00      1.00      1.00      1407
#
#        accuracy                           1.00      2400
#       macro avg       0.99      1.00      0.99      2400
#    weighted avg       1.00      1.00      1.00      2400

# %%
import os
import joblib
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Ensure the model directory exists
os.makedirs('model', exist_ok=True)

# Define the model file path
model_path = 'model/LSTM_model.h5'

# Reshape x_train and x_test if needed: (samples, timesteps, features)
# Example: if x_train is 2D, convert it to 3D
if len(x_train.shape) == 2:
    x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
    x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

if os.path.exists(model_path):
    # Load the trained LSTM model from the file
    lstm_model = load_model(model_path)
    print("LSTM model loaded successfully.")
    y_pred = lstm_model.predict(x_test)
    y_pred = np.argmax(y_pred, axis=1) if y_test.ndim == 1 else y_pred
    calculateMetrics("LSTM", y_pred, y_test)
else:
    # Define the LSTM model
    lstm_model = Sequential()
    lstm_model.add(LSTM(64, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
    lstm_model.add(Dense(1, activation='sigmoid'))  # Use 'softmax' for multi-class classification

    lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])  # Change loss if multi-class

    # Train the model
    lstm_model.fit(x_train, y_train, epochs=20, batch_size=32, validation_split=0.2,
                   callbacks=[EarlyStopping(patience=3, restore_best_weights=True)])

    # Save the trained LSTM model
    lstm_model.save(model_path)
    print("LSTM model saved successfully.")

    # Predict and evaluate
    y_pred = lstm_model.predict(x_test)
    y_pred = (y_pred > 0.5).astype(int)  # Binary classification thresholding
    calculateMetrics("LSTM", y_pred, y_test)
# Out:
# C:\Users\malle\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2900 - loss: -0.0369 - val_accuracy: 0.3745 - val_loss: -1.7163
# Epoch 2/20
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3631 - loss: -2.1037 - val_accuracy: 0.3745 - val_loss: -3.1398
# Epoch 3/20
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3620 - loss: -3.6845 - val_accuracy: 0.3745 - val_loss: -5.0511
# Epoch 4/20
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3615 - loss: -5.6953 - val_accuracy: 0.3745 - val_loss: -6.8882
# Epoch 5/20
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3614 - loss: -7.6387 - val_accuracy: 0.3745 - val_loss: -8.6891
# Epoch 6/20
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
import os
import joblib

# Flatten input if it's 3D
if len(x_train.shape) == 3:
    x_train = x_train.reshape(x_train.shape[0], -1)
    x_test = x_test.reshape(x_test.shape[0], -1)

# Ensure model directory exists
os.makedirs('model', exist_ok=True)
model_path = 'model/KNNClassifier.pkl'

if os.path.exists(model_path):
    knn = joblib.load(model_path)
    print("KNN model loaded successfully.")
else:
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(x_train, y_train)
    joblib.dump(knn, model_path)
    print("KNN model saved successfully.")

y_pred = knn.predict(x_test)
calculateMetrics("KNN", y_pred, y_test)
# Out:
# KNN model saved successfully.
# KNN Accuracy    : 84.625
# KNN Precision   : 77.96737022607955
# KNN Recall      : 73.46463640692761
# KNN FSCORE      : 75.37546477013424
#
#  KNN classification report
#                   precision    recall  f1-score   support
#
#      Unsuitable       0.49      0.63      0.55       101
#        Moderate       0.81      0.84      0.82       892
# Highly Suitable       0.91      0.87      0.89      1407
#
#        accuracy                           0.85      2400
#       macro avg       0.73      0.78      0.75      2400
#    weighted avg       0.85      0.85      0.85      2400

# %%
import os
import joblib
from sklearn.svm import SVC

# Ensure the model directory exists
os.makedirs('model', exist_ok=True)

# Define the model file path
model_path = 'model/SVM_model.pkl'

if os.path.exists(model_path):
    # Load the trained SVM model
    svm = joblib.load(model_path)
    print("SVM model loaded successfully.")
    y_pred = svm.predict(x_test)
    calculateMetrics("SVM", y_pred, y_test)
else:
    # Train the SVM model (assuming x_train and y_train are defined)
    svm = SVC(kernel='rbf', probability=True)  # You can change kernel to 'linear', 'poly', etc.
    svm.fit(x_train, y_train)

    # Save the trained model
    joblib.dump(svm, model_path)
    print("SVM model saved successfully.")

    y_pred = svm.predict(x_test)
    calculateMetrics("SVM", y_pred, y_test)
# Out:
# SVM model saved successfully.
# C:\Users\malle\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\malle\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
df.corr()
# Out:
#                             Region  Soil_Quality_Index  Annual_Rainfall_mm  \
# Region                    1.000000            0.010276           -0.016855
# Soil_Quality_Index        0.010276            1.000000            0.013371
# Annual_Rainfall_mm       -0.016855            0.013371            1.000000
# Temperature_C            -0.004312           -0.019979            0.002888
# Irrigation_Level          0.005080           -0.009829            0.012990
# CO2_Emission_Scenario     0.000098           -0.002630            0.004229
# Water_Availability_Index  0.008522            0.948087            0.010474
# Fertilizer_Access        -0.009677           -0.937402           -0.016388
# Land_Degradation_Risk     0.004886            0.557191            0.023540
# Land_Suitability         -0.001963           -0.574770           -0.244953
#
#                           Temperature_C  Irrigation_Level  \
# Region                        -0.004312          0.005080
# ...
